# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting easydict (from chembl_webresource_client)
#   Downloading easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: attrs>=21.2 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.1.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.8)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (2025.7.9)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading cattrs-25.1.1-py3-none-any.whl (69 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Downloading easydict-1.13-py3-none-any.whl (6.8 kB)
# Installing collected packages: easydict, url-normalize, cattrs, requests-cache, chembl_webresource_client
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [chembl_webresource_client]0m [chembl_webresource_client]
# Successfully installed cattrs-25.1.1 chembl_webresource_client-0.10.9 easydict-1.13 requests-cache-1.2.1 url-normalize-2.2.1

# %%
import sys
print(sys.executable)
# Out:
# /home/vp0240/micromamba/envs/drugdiscovery/bin/python

# %%
#import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Out:
# /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages/chembl_webresource_client/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                        Coronavirus
# 1               []                                 Feline coronavirus
# 2               []                                 Murine coronavirus
# 3               []                                 Canine coronavirus
# 4               []                             Human coronavirus 229E
# 5               []                             Human coronavirus OC43
# 6               []  Severe acute respiratory syndrome-related coro...
# 7               []  Middle East respiratory syndrome-related coron...
# 8               []  Severe acute respiratory syndrome-related coro...
# 9               []    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                 Feline coronavirus   14.0
# 2                                 Murine coronavirus   14.0
# 3                                 Canine coronavirus   14.0
# 4                             Human coronavirus 229E   13.0
# 5                             Human coronavirus OC43   13.0
# 6                SARS coronavirus 3C-like proteinase   10.0
# 7  Middle East respiratory syndrome-related coron...    9.0
# 8                          Replicase polyprotein 1ab    4.0
# 9                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612744
# 2               False    CHEMBL5209664
# 3               False    CHEMBL5291668
# 4               False     CHEMBL613837
# 5               False    CHEMBL5209665
# 6               False       CHEMBL3927
# 7               False    CHEMBL4296578
# 8               False       CHEMBL5118
# 9               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM    12663
# 2                                                 []        ORGANISM   694005
# 3                                                 []        ORGANISM    11153
# 4                                                 []        ORGANISM    11137
# 5                                                 []        ORGANISM    31631
# 6  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   694009
# 7                                                 []        ORGANISM  1335626
# 8  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   694009
# 9  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL613837'
