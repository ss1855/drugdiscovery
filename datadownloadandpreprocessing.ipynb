# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
import os
# Out:
# /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages/chembl_webresource_client/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version

# %% [markdown]
# # Search the chembl database for target organism/compound
# Returns the search result as dictionary. Convert it into dictionary

# %%
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                        Coronavirus
# 1               []                                 Feline coronavirus
# 2               []                                 Murine coronavirus
# 3               []                                 Canine coronavirus
# 4               []                             Human coronavirus 229E
# 5               []                             Human coronavirus OC43
# 6               []  Severe acute respiratory syndrome-related coro...
# 7               []  Middle East respiratory syndrome-related coron...
# 8               []  Severe acute respiratory syndrome-related coro...
# 9               []    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                 Feline coronavirus   14.0
# 2                                 Murine coronavirus   14.0
# 3                                 Canine coronavirus   14.0
# 4                             Human coronavirus 229E   13.0
# 5                             Human coronavirus OC43   13.0
# 6                SARS coronavirus 3C-like proteinase   10.0
# 7  Middle East respiratory syndrome-related coron...    9.0
# 8                          Replicase polyprotein 1ab    4.0
# 9                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612744
# 2               False    CHEMBL5209664
# 3               False    CHEMBL5291668
# 4               False     CHEMBL613837
# 5               False    CHEMBL5209665
# 6               False       CHEMBL3927
# 7               False    CHEMBL4296578
# 8               False       CHEMBL5118
# 9               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM    12663
# 2                                                 []        ORGANISM   694005
# 3                                                 []        ORGANISM    11153
# 4                                                 []        ORGANISM    11137
# 5                                                 []        ORGANISM    31631
# 6  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   694009
# 7                                                 []        ORGANISM  1335626
# 8  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   694009
# 9  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# Select the target you are interested in

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type = "IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 242  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 243  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 244  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 245  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 246  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# 0        1480935                                                 []
# 1        1480936                                                 []
# 2        1481061                                                 []
# 3        1481065                                                 []
# 4        1481066                                                 []
# ..           ...                                                ...
# 242     25516041  [{'comments': None, 'relation': '=', 'result_f...
# 243     25516042  [{'comments': None, 'relation': '=', 'result_f...
# 244     25516043  [{'comments': None, 'relation': '=', 'result_f...
# 245     25516044  [{'comments': None, 'relation': '=', 'result_f...
# 246     25516045  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2      CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ..              ...                                                ...
# 242   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 243   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 244   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 245   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 246   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 242          B                    None                   None  BAO_0000190
# 243          B                    None                   None  BAO_0000190
# 244          B                    None                   None  BAO_0000190
# 245          B                    None                   None  BAO_0000190
# 246          B                    None                   None  BAO_0000190
#
#      ...                                    target_organism  \
# 0    ...  Severe acute respiratory syndrome-related coro...
# 1    ...  Severe acute respiratory syndrome-related coro...
# 2    ...  Severe acute respiratory syndrome-related coro...
# 3    ...  Severe acute respiratory syndrome-related coro...
# 4    ...  Severe acute respiratory syndrome-related coro...
# ..   ...                                                ...
# 242  ...  Severe acute respiratory syndrome-related coro...
# 243  ...  Severe acute respiratory syndrome-related coro...
# 244  ...  Severe acute respiratory syndrome-related coro...
# 245  ...  Severe acute respiratory syndrome-related coro...
# 246  ...  Severe acute respiratory syndrome-related coro...
#
#                         target_pref_name target_tax_id text_value  toid  \
# 0    SARS coronavirus 3C-like proteinase        694009       None  None
# 1    SARS coronavirus 3C-like proteinase        694009       None  None
# 2    SARS coronavirus 3C-like proteinase        694009       None  None
# 3    SARS coronavirus 3C-like proteinase        694009       None  None
# 4    SARS coronavirus 3C-like proteinase        694009       None  None
# ..                                   ...           ...        ...   ...
# 242  SARS coronavirus 3C-like proteinase        694009       None  None
# 243  SARS coronavirus 3C-like proteinase        694009       None  None
# 244  SARS coronavirus 3C-like proteinase        694009       None  None
# 245  SARS coronavirus 3C-like proteinase        694009       None  None
# 246  SARS coronavirus 3C-like proteinase        694009       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    uM  UO_0000065        None    7.2
# 1     IC50    uM  UO_0000065        None    9.4
# 2     IC50    uM  UO_0000065        None   13.5
# 3     IC50    uM  UO_0000065        None  13.11
# 4     IC50    uM  UO_0000065        None    2.0
# ..     ...   ...         ...         ...    ...
# 242  pIC50  None  UO_0000065        None   6.42
# 243   IC50    uM  UO_0000065        None  0.165
# 244   IC50    uM  UO_0000065        None  0.161
# 245  pIC50  None  UO_0000065        None   6.78
# 246  pIC50  None  UO_0000065        None   6.79
#
# [247 rows x 46 columns]

# %%
os.makedirs("data", exist_ok=True)  # Create folder if it doesn't already exist
df.to_csv("data/bioactivity_data_raw.csv", index=False)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Handling Missing data and removing duplicate canonical_smiles
# If any compounds has missing value for the standard_value  and canonical smiles column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df2.canonical_smiles.notna()]

# %%
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 242  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 243  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 244  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 245  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 246  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# 0        1480935                                                 []
# 1        1480936                                                 []
# 2        1481061                                                 []
# 3        1481065                                                 []
# 4        1481066                                                 []
# ..           ...                                                ...
# 242     25516041  [{'comments': None, 'relation': '=', 'result_f...
# 243     25516042  [{'comments': None, 'relation': '=', 'result_f...
# 244     25516043  [{'comments': None, 'relation': '=', 'result_f...
# 245     25516044  [{'comments': None, 'relation': '=', 'result_f...
# 246     25516045  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2      CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ..              ...                                                ...
# 242   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 243   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 244   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 245   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 246   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 242          B                    None                   None  BAO_0000190
# 243          B                    None                   None  BAO_0000190
# 244          B                    None                   None  BAO_0000190
# 245          B                    None                   None  BAO_0000190
# 246          B                    None                   None  BAO_0000190
#
#      ...                                    target_organism  \
# 0    ...  Severe acute respiratory syndrome-related coro...
# 1    ...  Severe acute respiratory syndrome-related coro...
# 2    ...  Severe acute respiratory syndrome-related coro...
# 3    ...  Severe acute respiratory syndrome-related coro...
# 4    ...  Severe acute respiratory syndrome-related coro...
# ..   ...                                                ...
# 242  ...  Severe acute respiratory syndrome-related coro...
# 243  ...  Severe acute respiratory syndrome-related coro...
# 244  ...  Severe acute respiratory syndrome-related coro...
# 245  ...  Severe acute respiratory syndrome-related coro...
# 246  ...  Severe acute respiratory syndrome-related coro...
#
#                         target_pref_name target_tax_id text_value  toid  \
# 0    SARS coronavirus 3C-like proteinase        694009       None  None
# 1    SARS coronavirus 3C-like proteinase        694009       None  None
# 2    SARS coronavirus 3C-like proteinase        694009       None  None
# 3    SARS coronavirus 3C-like proteinase        694009       None  None
# 4    SARS coronavirus 3C-like proteinase        694009       None  None
# ..                                   ...           ...        ...   ...
# 242  SARS coronavirus 3C-like proteinase        694009       None  None
# 243  SARS coronavirus 3C-like proteinase        694009       None  None
# 244  SARS coronavirus 3C-like proteinase        694009       None  None
# 245  SARS coronavirus 3C-like proteinase        694009       None  None
# 246  SARS coronavirus 3C-like proteinase        694009       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    uM  UO_0000065        None    7.2
# 1     IC50    uM  UO_0000065        None    9.4
# 2     IC50    uM  UO_0000065        None   13.5
# 3     IC50    uM  UO_0000065        None  13.11
# 4     IC50    uM  UO_0000065        None    2.0
# ..     ...   ...         ...         ...    ...
# 242  pIC50  None  UO_0000065        None   6.42
# 243   IC50    uM  UO_0000065        None  0.165
# 244   IC50    uM  UO_0000065        None  0.161
# 245  pIC50  None  UO_0000065        None   6.78
# 246  pIC50  None  UO_0000065        None   6.79
#
# [245 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 184

# %%
duplicates = df2[df2.duplicated(subset='canonical_smiles', keep=False)][
    ['canonical_smiles', 'molecule_chembl_id', 'standard_value']
]

# %%
duplicates
# Out:
#                                       canonical_smiles molecule_chembl_id  \
# 22   O=C(CSc1nccc(-c2csc(-c3ccccc3)n2)n1)Nc1cc(Cl)c...       CHEMBL208732
# 23   O=C(CSc1nccc(-c2csc(-c3ccccc3)n2)n1)Nc1cc(Cl)c...       CHEMBL208732
# 24   COc1cccc(-c2nc(SCC(=O)Nc3ccc([N+](=O)[O-])cc3)...       CHEMBL210146
# 25   COc1cccc(-c2nc(SCC(=O)Nc3ccc([N+](=O)[O-])cc3)...       CHEMBL210146
# 26   CCOC(=O)c1cnc(SCC(=O)Nc2ccc([N+](=O)[O-])cc2)nc1N       CHEMBL207458
# ..                                                 ...                ...
# 242                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12      CHEMBL4590273
# 243                           S=C([S-])NCc1cccnc1.[K+]      CHEMBL5436771
# 244  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...      CHEMBL2365410
# 245                           S=C([S-])NCc1cccnc1.[K+]      CHEMBL5436771
# 246  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...      CHEMBL2365410
#
#     standard_value
# 22         3019.95
# 23          3000.0
# 24       301995.17
# 25        300000.0
# 26       251188.64
# ..             ...
# 242         380.19
# 243          165.0
# 244          161.0
# 245         165.96
# 246         162.18
#
# [104 rows x 3 columns]

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 238                                               None             None
# 239                                               None             None
# 241  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 243  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 244  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# 0        1480935                                                 []
# 1        1480936                                                 []
# 2        1481061                                                 []
# 3        1481065                                                 []
# 4        1481066                                                 []
# ..           ...                                                ...
# 238     18880176                                                 []
# 239     18880177                                                 []
# 241     25516040  [{'comments': None, 'relation': '=', 'result_f...
# 243     25516042  [{'comments': None, 'relation': '=', 'result_f...
# 244     25516043  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2      CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ..              ...                                                ...
# 238   CHEMBL4311688  Inhibition of SARS coronavirus 3Cl protease R1...
# 239   CHEMBL4311688  Inhibition of SARS coronavirus 3Cl protease R1...
# 241   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 243   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
# 244   CHEMBL5336133  Inhibition of SARS-CoV N-terminal 6His-SUMO-ta...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 238          B                    None                   None  BAO_0000190
# 239          B                    None                   None  BAO_0000190
# 241          B                    None                   None  BAO_0000190
# 243          B                    None                   None  BAO_0000190
# 244          B                    None                   None  BAO_0000190
#
#      ...                                    target_organism  \
# 0    ...  Severe acute respiratory syndrome-related coro...
# 1    ...  Severe acute respiratory syndrome-related coro...
# 2    ...  Severe acute respiratory syndrome-related coro...
# 3    ...  Severe acute respiratory syndrome-related coro...
# 4    ...  Severe acute respiratory syndrome-related coro...
# ..   ...                                                ...
# 238  ...  Severe acute respiratory syndrome-related coro...
# 239  ...  Severe acute respiratory syndrome-related coro...
# 241  ...  Severe acute respiratory syndrome-related coro...
# 243  ...  Severe acute respiratory syndrome-related coro...
# 244  ...  Severe acute respiratory syndrome-related coro...
#
#                         target_pref_name target_tax_id text_value  toid  type  \
# 0    SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 1    SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 2    SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 3    SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 4    SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# ..                                   ...           ...        ...   ...   ...
# 238  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 239  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 241  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 243  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
# 244  SARS coronavirus 3C-like proteinase        694009       None  None  IC50
#
#     units    uo_units upper_value   value
# 0      uM  UO_0000065        None     7.2
# 1      uM  UO_0000065        None     9.4
# 2      uM  UO_0000065        None    13.5
# 3      uM  UO_0000065        None   13.11
# 4      uM  UO_0000065        None     2.0
# ..    ...         ...         ...     ...
# 238    uM  UO_0000065        None  1000.0
# 239    uM  UO_0000065        None  2000.0
# 241    uM  UO_0000065        None   0.383
# 243    uM  UO_0000065        None   0.165
# 244    uM  UO_0000065        None   0.161
#
# [184 rows x 46 columns]

# %% [markdown]
# Check and remove any canonical duplicates and remove duplicate entry keeping only the first appearance in dataframe

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3 = df3.reset_index(drop=True)
df3.to_csv("data/bioactivity_data_preprocessed.csv", index=False)

# %% [markdown]
# ## Data Labelling

# %%
bioactivity_class = []
for i in df3.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("Inactive")
    elif float(i) <= 1000:
        bioactivity_class.append("Active")
    else:
        bioactivity_class.append("Intermediate")

# %%
len(bioactivity_class)
# Out:
# 184

# %%
bioactivity_class = pd.Series(bioactivity_class, name='class')

# %%
bioactivity_class
# Out:
# 0      Intermediate
# 1      Intermediate
# 2          Inactive
# 3          Inactive
# 4      Intermediate
#            ...
# 179        Inactive
# 180        Inactive
# 181          Active
# 182          Active
# 183          Active
# Name: class, Length: 184, dtype: object

# %%
df4 = pd.concat([df3,bioactivity_class],axis =1 )

# %%
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 179      CHEMBL4437284  CON(C)C(=O)[C@H](Cc1c[nH]cn1)NC[C@@H]1C(NC(=O)...
# 180      CHEMBL4459894  CCOC(=O)/C=C/[C@H](Cc1c[nH]cn1)NC[C@@H]1C(NC(=...
# 181      CHEMBL4590273                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 182      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 183      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
#
#     standard_value         class
# 0           7200.0  Intermediate
# 1           9400.0  Intermediate
# 2          13500.0      Inactive
# 3          13110.0      Inactive
# 4           2000.0  Intermediate
# ..             ...           ...
# 179      1000000.0      Inactive
# 180      2000000.0      Inactive
# 181          383.0        Active
# 182          165.0        Active
# 183          161.0        Active
#
# [184 rows x 4 columns]

# %%
df4.to_csv("data/bioactivity_data_curated.csv", index=False)
