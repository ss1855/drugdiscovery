# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.16-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from lazypredict) (8.2.1)
# Requirement already satisfied: scikit-learn in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from lazypredict) (1.7.2)
# Requirement already satisfied: pandas in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from lazypredict) (2.3.1)
# Collecting tqdm (from lazypredict)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: joblib in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from lazypredict) (1.5.2)
# Collecting lightgbm (from lazypredict)
#   Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl.metadata (17 kB)
# Collecting xgboost (from lazypredict)
#   Downloading xgboost-3.0.5-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting pytest-runner (from lazypredict)
#   Downloading pytest_runner-6.0.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting mlflow>=2.0.0 (from lazypredict)
#   Downloading mlflow-3.3.2-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==3.3.2 (from mlflow>=2.0.0->lazypredict)
#   Downloading mlflow_skinny-3.3.2-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.3.2 (from mlflow>=2.0.0->lazypredict)
#   Downloading mlflow_tracing-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: Flask<4 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow>=2.0.0->lazypredict) (3.1.1)
# Collecting alembic!=1.10.0,<2 (from mlflow>=2.0.0->lazypredict)
#   Downloading alembic-1.16.5-py3-none-any.whl.metadata (7.3 kB)
# Collecting cryptography<46,>=43.0.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow>=2.0.0->lazypredict)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow>=2.0.0->lazypredict)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow>=2.0.0->lazypredict) (3.10.3)
# Requirement already satisfied: numpy<3 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow>=2.0.0->lazypredict) (2.3.1)
# Collecting pyarrow<22,>=4.0.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: scipy<2 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow>=2.0.0->lazypredict) (1.16.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow>=2.0.0->lazypredict) (2.0.41)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading cachetools-6.2.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading databricks_sdk-0.65.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_api-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (25.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading pydantic-2.11.8-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (2.32.4)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (4.14.1)
# Collecting uvicorn<1 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=1.14 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from cryptography<46,>=43.0.0->mlflow>=2.0.0->lazypredict) (1.17.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (2.5.0)
# Collecting starlette<0.48.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading starlette-0.47.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: blinker>=1.9.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.3)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=2.0.0->lazypredict)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=2.0.0->lazypredict)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (2.9.0.post0)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (3.2.3)
# Collecting opentelemetry-semantic-conventions==0.58b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from pandas->lazypredict) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=2.0.0->lazypredict) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (2025.7.14)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from scikit-learn->lazypredict) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazypredict) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from uvicorn<1->mlflow-skinny==3.3.2->mlflow>=2.0.0->lazypredict) (0.16.0)
# Requirement already satisfied: pycparser in /home/vp0240/micromamba/envs/drugdiscovery/lib/python3.11/site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.22)
# Collecting nvidia-nccl-cu12 (from xgboost->lazypredict)
#   Downloading nvidia_nccl_cu12-2.28.3-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Downloading lazypredict-0.2.16-py2.py3-none-any.whl (14 kB)
# Downloading mlflow-3.3.2-py3-none-any.whl (26.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 25.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading mlflow_skinny-3.3.2-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 6.2 MB/s eta 0:00:00.4 MB/s eta 0:00:01
# Downloading mlflow_tracing-3.3.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.7 MB/s eta 0:00:00.1 MB/s eta 0:00:01
# Downloading alembic-1.16.5-py3-none-any.whl (247 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 15.4 MB/s eta 0:00:00m eta 0:00:01
# Downloading databricks_sdk-0.65.0-py3-none-any.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.9/705.9 kB 2.0 MB/s eta 0:00:0031m111.1 MB/s eta 0:00:01
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.116.1-py3-none-any.whl (95 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading opentelemetry_api-1.37.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl (131 kB)
# Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl (207 kB)
# Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
# Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 24.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading pydantic-2.11.8-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.7 MB/s eta 0:00:00113.3 MB/s eta 0:00:01
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.47.3-py3-none-any.whl (72 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 13.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading pytest_runner-6.0.1-py3-none-any.whl (7.2 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading xgboost-3.0.5-py3-none-manylinux_2_28_x86_64.whl (94.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 MB 28.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_nccl_cu12-2.28.3-py3-none-manylinux_2_18_x86_64.whl (295.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.9/295.9 MB 2.3 MB/s eta 0:00:00m eta 0:00:010:00:04
# Installing collected packages: zipp, uvicorn, typing-inspection, tqdm, sqlparse, smmap, pytest-runner, pydantic-core, pyasn1, pyarrow, protobuf, nvidia-nccl-cu12, Mako, gunicorn, graphql-core, cloudpickle, cachetools, annotated-types, xgboost, starlette, rsa, pydantic, pyasn1-modules, lightgbm, importlib_metadata, graphql-relay, gitdb, docker, cryptography, alembic, opentelemetry-api, graphene, google-auth, gitpython, fastapi, opentelemetry-semantic-conventions, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow, lazypredict
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42/42 [lazypredict]m [lazypredict]m [mlflow]skinny]]dk]onventions]
# Successfully installed Mako-1.3.10 alembic-1.16.5 annotated-types-0.7.0 cachetools-5.5.2 cloudpickle-3.1.1 cryptography-45.0.7 databricks-sdk-0.65.0 docker-7.1.0 fastapi-0.116.1 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.40.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 importlib_metadata-8.7.0 lazypredict-0.2.16 lightgbm-4.6.0 mlflow-3.3.2 mlflow-skinny-3.3.2 mlflow-tracing-3.3.2 nvidia-nccl-cu12-2.28.3 opentelemetry-api-1.37.0 opentelemetry-sdk-1.37.0 opentelemetry-semantic-conventions-0.58b0 protobuf-6.32.1 pyarrow-21.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.8 pydantic-core-2.33.2 pytest-runner-6.0.1 rsa-4.9.1 smmap-5.0.2 sqlparse-0.5.3 starlette-0.47.3 tqdm-4.67.1 typing-inspection-0.4.1 uvicorn-0.35.0 xgboost-3.0.5 zipp-3.23.0

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## **2. Load the data set**

# %%
df = pd.read_csv('data/bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (6641, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (6641, 144)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000725 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 432
# [LightGBM] [Info] Number of data points in the train set: 5312, number of used features: 144
# [LightGBM] [Info] Start training from score 5.812101
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000923 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 432
# [LightGBM] [Info] Number of data points in the train set: 5312, number of used features: 144
# [LightGBM] [Info] Start training from score 5.812101

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreeRegressor                           0.94       0.94  0.39        0.10
# DecisionTreeRegressor                        0.94       0.94  0.39        0.12
# ExtraTreesRegressor                          0.94       0.94  0.39        6.33
# GaussianProcessRegressor                     0.94       0.94  0.39        5.24
# RandomForestRegressor                        0.91       0.91  0.46        4.43
# XGBRegressor                                 0.90       0.90  0.49        0.19
# BaggingRegressor                             0.90       0.90  0.50        0.50
# MLPRegressor                                 0.89       0.89  0.51        4.95
# HistGradientBoostingRegressor                0.76       0.77  0.75        0.43
# KNeighborsRegressor                          0.75       0.75  0.78        0.15
# LGBMRegressor                                0.74       0.75  0.79        0.14
# SVR                                          0.68       0.69  0.87        3.75
# NuSVR                                        0.67       0.68  0.89        2.93
# GradientBoostingRegressor                    0.51       0.53  1.07        1.41
# TransformedTargetRegressor                   0.37       0.39  1.22        0.07
# LinearRegression                             0.37       0.39  1.22        0.18
# Ridge                                        0.37       0.39  1.22        0.05
# LassoLarsCV                                  0.37       0.38  1.22        0.23
# RidgeCV                                      0.37       0.38  1.22        0.21
# LassoLarsIC                                  0.37       0.38  1.23        0.22
# LassoCV                                      0.37       0.38  1.23        1.80
# ElasticNetCV                                 0.37       0.38  1.23        1.58
# BayesianRidge                                0.36       0.38  1.23        0.24
# SGDRegressor                                 0.35       0.37  1.24        0.10
# HuberRegressor                               0.35       0.37  1.24        7.91
# LinearSVR                                    0.33       0.35  1.26        0.66
# PoissonRegressor                             0.31       0.33  1.28        3.92
# OrthogonalMatchingPursuit                    0.25       0.27  1.34        0.03
# OrthogonalMatchingPursuitCV                  0.25       0.27  1.34        0.07
# AdaBoostRegressor                            0.25       0.27  1.34        0.83
# GammaRegressor                               0.24       0.26  1.34        1.73
# TweedieRegressor                             0.24       0.26  1.34        1.81
# PassiveAggressiveRegressor                   0.13       0.16  1.43        0.08
# LarsCV                                       0.11       0.14  1.45        0.26
# Lars                                         0.02       0.05  1.52        0.06
# ElasticNet                                  -0.03       0.00  1.56        0.04
# DummyRegressor                              -0.03       0.00  1.56        0.03
# LassoLars                                   -0.03       0.00  1.56        0.06
# Lasso                                       -0.03       0.00  1.56        0.13
# QuantileRegressor                           -0.05      -0.02  1.57        1.50
# RANSACRegressor                             -3.91      -3.78  3.41       12.02
# KernelRidge                                -13.89     -13.48  5.94        0.93

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# XGBRegressor                                 0.65       0.69  0.86        0.16
# RandomForestRegressor                        0.65       0.69  0.86        4.29
# HistGradientBoostingRegressor                0.62       0.66  0.90        0.35
# BaggingRegressor                             0.61       0.66  0.91        0.48
# MLPRegressor                                 0.59       0.64  0.93        5.14
# LGBMRegressor                                0.59       0.63  0.94        0.14
# SVR                                          0.57       0.62  0.96        2.10
# KNeighborsRegressor                          0.57       0.61  0.96        0.08
# NuSVR                                        0.56       0.61  0.97        1.72
# ExtraTreesRegressor                          0.49       0.54  1.05        6.27
# DecisionTreeRegressor                        0.44       0.51  1.09        0.11
# ExtraTreeRegressor                           0.44       0.50  1.10        0.11
# GradientBoostingRegressor                    0.43       0.49  1.11        1.45
# RidgeCV                                      0.28       0.35  1.25        0.19
# ElasticNetCV                                 0.28       0.35  1.25        1.50
# LassoCV                                      0.28       0.35  1.25        1.60
# LassoLarsCV                                  0.28       0.35  1.25        0.23
# LassoLarsIC                                  0.27       0.35  1.25        0.21
# BayesianRidge                                0.27       0.35  1.25        0.29
# Ridge                                        0.27       0.35  1.25        0.05
# TransformedTargetRegressor                   0.27       0.35  1.25        0.05
# LinearRegression                             0.27       0.35  1.25        0.28
# SGDRegressor                                 0.27       0.35  1.25        0.09
# HuberRegressor                               0.27       0.35  1.25        7.15
# PoissonRegressor                             0.25       0.33  1.27        4.11
# LinearSVR                                    0.24       0.32  1.27        0.66
# TweedieRegressor                             0.19       0.28  1.32        1.76
# GammaRegressor                               0.19       0.28  1.32        1.59
# OrthogonalMatchingPursuitCV                  0.19       0.28  1.32        0.07
# OrthogonalMatchingPursuit                    0.19       0.28  1.32        0.03
# AdaBoostRegressor                            0.11       0.21  1.38        0.79
# LarsCV                                       0.05       0.15  1.43        0.25
# PassiveAggressiveRegressor                  -0.01       0.10  1.47        0.07
# ElasticNet                                  -0.12      -0.00  1.55        0.03
# DummyRegressor                              -0.12      -0.00  1.55        0.02
# LassoLars                                   -0.12      -0.00  1.55        0.08
# Lasso                                       -0.12      -0.00  1.55        0.08
# QuantileRegressor                           -0.13      -0.01  1.56        1.43
# Lars                                        -0.22      -0.09  1.61        0.06
# RANSACRegressor                             -4.88      -4.25  3.55       11.32
# GaussianProcessRegressor                    -6.04      -5.27  3.88        3.30
# KernelRidge                                -14.99     -13.26  5.85        0.81

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
